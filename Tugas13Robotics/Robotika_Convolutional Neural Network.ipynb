# %%
#Mochamad Phillia Wibowo_1103204191_TK-44-G7

# %%
# !wget --no-check-certificate \   https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \   -O /tmp/Chessman-image-dataset.zip
# Out:
# --2023-12-28 07:38:19--  http://%20/
# Resolving   ( )... failed: Name or service not known.
# wget: unable to resolve host address ‘ ’
# --2023-12-28 07:38:19--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2023-12-28 07:38:19--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   223MB/s    in 0.3s
#
# 2023-12-28 07:38:20 (223 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]
#
# --2023-12-28 07:38:20--  http://%20/
# Resolving   ( )... failed: Name or service not known.
# wget: unable to resolve host address ‘ ’
# FINISHED --2023-12-28 07:38:20--
# Total wall clock time: 0.8s
# Downloaded: 1 files, 58M in 0.3s (223 MB/s)

# %%
#ekstrak dataset
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
#melihat direktori dataset
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Pawn', 'Queen', 'Bishop', 'Knight', 'Rook', 'King']

# %%
#menghitung jumlah data pada tiap direktori
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
print('total bishop images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Bishop')))
print('total queen images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Queen')))
print('total rook images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Rook')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106
# total bishop images : 87
# total queen images : 78
# total rook images : 102

# %%
#melihat salah satu sample dataset
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
#import image generator dan mengaplikasikan augmentasi gambar
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   zoom_range=0.2,
                                   shear_range=0.2,
                                   fill_mode='nearest',
                                   validation_split=0.1) #set validation split

# %%
#membagi data training dan data testing menggunakan parameter subset 'training'/'validation'
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training' )

#set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, #direktori yang sama dengan data train
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
    )
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
#arsitektur model 3 layer convolution dan 2 hidden layer; 512 dan 256 unit perseptron
import tensorflow as tf
model = tf.keras.models.Sequential([
    #input shape 150x150 pixel dan 3 bytes warna
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    #flatten the result to feed into a DNN
    tf.keras.layers.Flatten(),
    #512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    #output dengan 1 neuron
    tf.keras.layers.Dense(6, activation='softmax') ])

# %%
#optimizer dan loss
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_generator,
                    validation_data=validation_generator,
                    epochs=50,
                    verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 39s - loss: 1.8312 - accuracy: 0.1623 - val_loss: 1.7886 - val_accuracy: 0.1923 - 39s/epoch - 618ms/step
# Epoch 2/50
# 63/63 - 37s - loss: 1.7907 - accuracy: 0.1884 - val_loss: 1.7864 - val_accuracy: 0.1923 - 37s/epoch - 586ms/step
# Epoch 3/50
# 63/63 - 39s - loss: 1.7867 - accuracy: 0.1924 - val_loss: 1.7833 - val_accuracy: 0.1923 - 39s/epoch - 614ms/step
# Epoch 4/50
# 63/63 - 37s - loss: 1.7845 - accuracy: 0.1924 - val_loss: 1.7798 - val_accuracy: 0.1923 - 37s/epoch - 585ms/step
# Epoch 5/50
# 63/63 - 45s - loss: 1.7856 - accuracy: 0.1924 - val_loss: 1.7816 - val_accuracy: 0.1731 - 45s/epoch - 717ms/step
# Epoch 6/50
# 63/63 - 40s - loss: 1.7767 - accuracy: 0.1924 - val_loss: 1.7818 - val_accuracy: 0.1923 - 40s/epoch - 636ms/step
# Epoch 7/50
# 63/63 - 38s - loss: 1.7749 - accuracy: 0.1984 - val_loss: 1.7795 - val_accuracy: 0.2308 - 38s/epoch - 603ms/step
# Epoch 8/50
# 63/63 - 41s - loss: 1.7404 - accuracy: 0.2425 - val_loss: 1.7848 - val_accuracy: 0.2115 - 41s/epoch - 645ms/step
# Epoch 9/50
# 63/63 - 40s - loss: 1.7403 - accuracy: 0.2385 - val_loss: 1.7633 - val_accuracy: 0.2115 - 40s/epoch - 641ms/step
# Epoch 10/50
# 63/63 - 38s - loss: 1.7202 - accuracy: 0.2585 - val_loss: 1.7287 - val_accuracy: 0.3269 - 38s/epoch - 601ms/step
# Epoch 11/50
# 63/63 - 38s - loss: 1.6485 - accuracy: 0.3046 - val_loss: 1.7502 - val_accuracy: 0.1731 - 38s/epoch - 610ms/step
# Epoch 12/50
# 63/63 - 41s - loss: 1.6947 - accuracy: 0.2986 - val_loss: 1.7640 - val_accuracy: 0.3077 - 41s/epoch - 644ms/step
# Epoch 13/50
# 63/63 - 39s - loss: 1.6144 - accuracy: 0.3166 - val_loss: 1.6484 - val_accuracy: 0.2692 - 39s/epoch - 627ms/step
# Epoch 14/50
# 63/63 - 37s - loss: 1.5895 - accuracy: 0.3347 - val_loss: 1.6015 - val_accuracy: 0.2692 - 37s/epoch - 591ms/step
# Epoch 15/50
# 63/63 - 38s - loss: 1.4944 - accuracy: 0.4008 - val_loss: 1.6680 - val_accuracy: 0.3077 - 38s/epoch - 607ms/step
# Epoch 16/50
# 63/63 - 38s - loss: 1.5056 - accuracy: 0.3747 - val_loss: 1.5679 - val_accuracy: 0.4038 - 38s/epoch - 610ms/step
# Epoch 17/50
# 63/63 - 39s - loss: 1.4619 - accuracy: 0.4228 - val_loss: 1.4610 - val_accuracy: 0.4615 - 39s/epoch - 619ms/step
# Epoch 18/50
# 63/63 - 39s - loss: 1.4338 - accuracy: 0.4188 - val_loss: 1.6098 - val_accuracy: 0.2692 - 39s/epoch - 619ms/step
# Epoch 19/50
# 63/63 - 45s - loss: 1.3508 - accuracy: 0.4509 - val_loss: 1.5563 - val_accuracy: 0.3462 - 45s/epoch - 708ms/step
# Epoch 20/50
# 63/63 - 38s - loss: 1.3464 - accuracy: 0.4770 - val_loss: 1.6289 - val_accuracy: 0.3269 - 38s/epoch - 610ms/step
# Epoch 21/50
# 63/63 - 38s - loss: 1.2780 - accuracy: 0.4970 - val_loss: 1.5030 - val_accuracy: 0.3654 - 38s/epoch - 610ms/step
# Epoch 22/50
# 63/63 - 39s - loss: 1.1713 - accuracy: 0.5411 - val_loss: 1.5406 - val_accuracy: 0.4038 - 39s/epoch - 619ms/step
# Epoch 23/50
# 63/63 - 37s - loss: 1.2086 - accuracy: 0.5411 - val_loss: 1.5446 - val_accuracy: 0.3846 - 37s/epoch - 587ms/step
# Epoch 24/50
# 63/63 - 37s - loss: 1.1486 - accuracy: 0.5731 - val_loss: 1.4507 - val_accuracy: 0.4423 - 37s/epoch - 582ms/step
# Epoch 25/50
# 63/63 - 38s - loss: 1.1368 - accuracy: 0.5431 - val_loss: 1.5681 - val_accuracy: 0.3462 - 38s/epoch - 598ms/step
# Epoch 26/50
# 63/63 - 37s - loss: 1.0931 - accuracy: 0.5752 - val_loss: 1.3720 - val_accuracy: 0.4808 - 37s/epoch - 585ms/step
# Epoch 27/50
# 63/63 - 37s - loss: 0.9947 - accuracy: 0.6493 - val_loss: 1.5409 - val_accuracy: 0.4038 - 37s/epoch - 584ms/step
# Epoch 28/50
# 63/63 - 36s - loss: 1.0190 - accuracy: 0.6092 - val_loss: 1.4978 - val_accuracy: 0.4423 - 36s/epoch - 569ms/step
# Epoch 29/50
# 63/63 - 38s - loss: 1.0062 - accuracy: 0.6212 - val_loss: 1.5102 - val_accuracy: 0.4423 - 38s/epoch - 604ms/step
# Epoch 30/50
# 63/63 - 38s - loss: 0.9007 - accuracy: 0.6493 - val_loss: 1.3884 - val_accuracy: 0.4615 - 38s/epoch - 604ms/step
# Epoch 31/50
# 63/63 - 35s - loss: 0.9336 - accuracy: 0.6493 - val_loss: 1.4722 - val_accuracy: 0.5192 - 35s/epoch - 563ms/step
# Epoch 32/50
# 63/63 - 37s - loss: 0.9015 - accuracy: 0.6774 - val_loss: 1.6069 - val_accuracy: 0.3846 - 37s/epoch - 583ms/step
# Epoch 33/50
# 63/63 - 37s - loss: 0.8316 - accuracy: 0.6874 - val_loss: 1.6619 - val_accuracy: 0.4615 - 37s/epoch - 591ms/step
# Epoch 34/50
# 63/63 - 46s - loss: 0.9058 - accuracy: 0.6754 - val_loss: 1.5020 - val_accuracy: 0.4808 - 46s/epoch - 727ms/step
# Epoch 35/50
# 63/63 - 36s - loss: 0.7779 - accuracy: 0.7114 - val_loss: 1.4524 - val_accuracy: 0.5385 - 36s/epoch - 566ms/step
# Epoch 36/50
# 63/63 - 36s - loss: 0.8335 - accuracy: 0.7094 - val_loss: 1.6508 - val_accuracy: 0.3462 - 36s/epoch - 576ms/step
# Epoch 37/50
# 63/63 - 38s - loss: 0.7395 - accuracy: 0.7375 - val_loss: 1.5026 - val_accuracy: 0.4231 - 38s/epoch - 606ms/step
# Epoch 38/50
# 63/63 - 36s - loss: 0.7684 - accuracy: 0.7134 - val_loss: 1.2637 - val_accuracy: 0.5000 - 36s/epoch - 575ms/step
# Epoch 39/50
# 63/63 - 36s - loss: 0.6765 - accuracy: 0.7395 - val_loss: 1.3254 - val_accuracy: 0.5192 - 36s/epoch - 570ms/step
# Epoch 40/50
# 63/63 - 36s - loss: 0.7311 - accuracy: 0.7415 - val_loss: 1.4021 - val_accuracy: 0.5000 - 36s/epoch - 573ms/step
# Epoch 41/50
# 63/63 - 37s - loss: 0.6871 - accuracy: 0.7415 - val_loss: 1.6249 - val_accuracy: 0.4615 - 37s/epoch - 587ms/step
# Epoch 42/50
# 63/63 - 39s - loss: 0.6429 - accuracy: 0.7655 - val_loss: 1.5359 - val_accuracy: 0.4808 - 39s/epoch - 613ms/step
# Epoch 43/50
# 63/63 - 35s - loss: 0.6405 - accuracy: 0.7776 - val_loss: 1.5139 - val_accuracy: 0.4231 - 35s/epoch - 560ms/step
# Epoch 44/50
# 63/63 - 39s - loss: 0.6350 - accuracy: 0.7535 - val_loss: 1.5713 - val_accuracy: 0.4423 - 39s/epoch - 618ms/step
# Epoch 45/50
# 63/63 - 37s - loss: 0.6656 - accuracy: 0.7655 - val_loss: 1.2283 - val_accuracy: 0.5385 - 37s/epoch - 590ms/step
# Epoch 46/50
# 63/63 - 36s - loss: 0.6037 - accuracy: 0.7715 - val_loss: 1.3721 - val_accuracy: 0.5192 - 36s/epoch - 577ms/step
# Epoch 47/50
# 63/63 - 36s - loss: 0.6381 - accuracy: 0.7595 - val_loss: 1.3425 - val_accuracy: 0.4423 - 36s/epoch - 569ms/step
# Epoch 48/50
# 63/63 - 44s - loss: 0.5737 - accuracy: 0.7896 - val_loss: 1.6191 - val_accuracy: 0.5385 - 44s/epoch - 700ms/step
# Epoch 49/50
# 63/63 - 37s - loss: 0.5447 - accuracy: 0.8116 - val_loss: 1.5618 - val_accuracy: 0.4615 - 37s/epoch - 580ms/step
# Epoch 50/50
# 63/63 - 37s - loss: 0.5316 - accuracy: 0.8036 - val_loss: 1.4315 - val_accuracy: 0.5577 - 37s/epoch - 585ms/step

# %%
#plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#plot akurasi
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
